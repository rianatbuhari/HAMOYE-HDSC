# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
FBS = pd.read_csv('FoodBalanceSheets.csv', encoding='ISO-8859-1')
FBS.shape
# Out:
# (60943, 12)

# %%
FBS.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
FBS.tail()
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 60938                                    Food      1000 tonnes  42.00  46.00
# 60939     Food supply quantity (kg/capita/yr)               kg   3.06   3.33
# 60940           Food supply (kcal/capita/day)  kcal/capita/day   3.00   4.00
# 60941  Protein supply quantity (g/capita/day)     g/capita/day   0.10   0.11
# 60942      Fat supply quantity (g/capita/day)     g/capita/day   0.04   0.05
#
#        Y2016  Y2017  Y2018
# 60938  33.00  19.00  16.00
# 60939   2.35   1.33   1.08
# ...

# %%
FBS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
FBS.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
#what is the total sum of animal fat produced in 2014 and 2017 respectively
fb = FBS.groupby(['Item'])
fb.sum()
# answer = 209460, 269617
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
#what is the mean and standard devaition for the year 2015
fb = FBS['Y2015']
fb.describe()
# answer = 135.256, 1603.403
# Out:
# count     59395.000000
# mean        135.235966
# std        1603.403984
# min       -3161.000000
# 25%           0.000000
# 50%           0.080000
# 75%           8.460000
# max      181137.000000
# Name: Y2015, dtype: float64

# %%
#what is the total number and percentage of missing data in 2016
FBS.isnull().sum()
# answer = 1535
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
#which year had the highest correlation with element code
FBS.corr()
# answer = 2014
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
#which year has the highest sum of import quantity
fb = FBS.groupby('Element')
fb.sum()
# answer = 2017
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
#what is the total number of production in 2014
fb = FBS.groupby(['Element'])
fb.sum().T
# answer = 19131287.75
# Out:
# Element       Domestic supply quantity  Export Quantity  \
# Area Code                    708993.00        599910.00
# Item Code                  14197445.00      11840553.00
# Element Code               28068795.00      26026133.00
# Y2014                       1996716.35        150020.64
# Y2015                       2021493.55        157614.47
# Y2016                       2044842.70        151920.46
# Y2017                       2088198.10        182338.80
# Y2018                       2161192.10        181594.80
#
# Element       Fat supply quantity (g/capita/day)        Feed         Food  \
# Area Code                              675050.00   176272.00    663295.00
# Item Code                            13535000.00  3538507.00  13285035.00
# Element Code                          3435732.00  7282199.00  25406622.00
# Y2014                                   10225.56   216927.89   1212332.49
# Y2015                                   10235.74   225050.22   1232361.10
# ...

# %%
#which of these element had the highest sum in 2018
fb = FBS.groupby(['Element'])
fb.sum().T
# answer = domestic supply quantity
# Out:
# Element       Domestic supply quantity  Export Quantity  \
# Area Code                    708993.00        599910.00
# Item Code                  14197445.00      11840553.00
# Element Code               28068795.00      26026133.00
# Y2014                       1996716.35        150020.64
# Y2015                       2021493.55        157614.47
# Y2016                       2044842.70        151920.46
# Y2017                       2088198.10        182338.80
# Y2018                       2161192.10        181594.80
#
# Element       Fat supply quantity (g/capita/day)        Feed         Food  \
# Area Code                              675050.00   176272.00    663295.00
# Item Code                            13535000.00  3538507.00  13285035.00
# Element Code                          3435732.00  7282199.00  25406622.00
# Y2014                                   10225.56   216927.89   1212332.49
# Y2015                                   10235.74   225050.22   1232361.10
# ...

# %%
#which of these element had the third lowest sum in 2018
fb = FBS.groupby(['Element'])
fb.sum().T
# answer = protein supply quantity
# Out:
# Element       Domestic supply quantity  Export Quantity  \
# Area Code                    708993.00        599910.00
# Item Code                  14197445.00      11840553.00
# Element Code               28068795.00      26026133.00
# Y2014                       1996716.35        150020.64
# Y2015                       2021493.55        157614.47
# Y2016                       2044842.70        151920.46
# Y2017                       2088198.10        182338.80
# Y2018                       2161192.10        181594.80
#
# Element       Fat supply quantity (g/capita/day)        Feed         Food  \
# Area Code                              675050.00   176272.00    663295.00
# Item Code                            13535000.00  3538507.00  13285035.00
# Element Code                          3435732.00  7282199.00  25406622.00
# Y2014                                   10225.56   216927.89   1212332.49
# Y2015                                   10235.74   225050.22   1232361.10
# ...

# %%
#what is the total import quantity in australia in 2018
fb = FBS.groupby(['Area','Element'])
fb.sum().T
# answer = 36238.29
# Out:
# Area                          Algeria                  \
# Element      Domestic supply quantity Export Quantity
# Area Code                      464.00          392.00
# Item Code                   311204.00       264011.00
# Element Code                614916.00       579278.00
# Y2014                        83755.94         1328.64
# Y2015                        85972.86         1104.62
# Y2016                        87157.61         1340.22
# Y2017                        86810.42         1494.54
# Y2018                        90023.42          811.54
#
# Area                                                                   \
# Element      Fat supply quantity (g/capita/day)       Feed       Food
# Area Code                                432.00      88.00     420.00
# Item Code                             291489.00   58967.00  282744.00
# Element Code                           73872.00  121462.00  539910.00
# Y2014                                    320.19    9656.04   60582.69
# ...

# %%
#total numbers of unique countries
FBS['Area'].nunique()
#answer = 49
# Out:
# 49
